# %% [markdown]
# # MVP - Sprint 1
#
# ## Profs. Tatiana Escovedo e Hugo Villamizar
#
# ### Aluno: Gláucio Canha

# %% [markdown]
# O que não está detalhado ou pode ser melhorado neste notebook para ficar como esperamos para o MVP:
# - Blocos de texto que expliquem textualmente cada etapa e cada decisão do seu código, contando uma história completa e compreensível, do início ao fim;
# - Boas práticas de codificação;
# - Após cada gráfico, escrever 1 parágrafo resumindo os principais achados, analisando os resultados e levantando eventuais pontos de atenção.

# %% [markdown]
# ## 1. Definição do Problema

# %% [markdown]
# O dataset utilizado no escopo deste projeto foi o MICRODADOS_ENEM_2021, disponibilizado no site https://www.gov.br/inep/pt-br/acesso-a-informacao/dados-abertos/microdados/enem pelo Instituto Nacional de Estudos e Pesquisas Educacionais Anisio Teixeira (INEP) O Exame Nacional do Ensino Médio (Enem) tem como objetivo primordial aferir se aqueles que dele participam demonstram, ao final do ensino médio, individualmente, domínio dos princípios científicos e tecnológicos que presidem a produção moderna e se detêm conhecimento das formas contemporâneas de linguagem. Os microdados do Enem são o menor nível de desagregação de dados recolhidos por meio do exame. O Data set apresenta muitos atributos relacionados a faixa etaria, sexo, cor/raça , tipo de escola que estudou, ano de conclusão do ensino médio, a pontuação obtida nas áreas de conhecimento e redação. O Problema apresentado é de aprendizado não supervisionado com a caracteristica de clusterização. Dependendo da forma de cálculo de pontuação por universidade, o candidato é classificado ou não. Queremos nesse estudo fazer correlaçãoes entre a pontuação entre áreas, por estado/municipio. A relação de notas entre o questionário socio-economico e a pontuação nas áreas de conecimento e redação. Os dados são anonimizaveis, não sendo possivel identificar um candidato ou mesmo a Instituição que o aluno estudou.
#
# **Dicionario inicial de dados:**
#
# | Variável | Descrição |
# | --- | --- |
# | U_INSCRICAO | Número de inscrição1 |
# | NU_ANO | Ano do Enem |
# | TP_FAIXA_ETARIA | Faixa etária |
# | TP_SEXO | Sexo |
# | TP_ESTADO_CIVIL | Estado Civil |
# | TP_COR_RACA | Cor/raça |
# | TP_NACIONALIDADE | Nacionalidade |
# | TP_ST_CONCLUSAO | Situação de conclusão do Ensino Médio |
# | TP_ANO_CONCLUIU | Ano de Conclusão do Ensino Médio |
# | TP_ESCOLA | Tipo de escola do Ensino Médio |
# | TP_ENSINO | Tipo de instituição que concluiu ou concluirá o Ensino Médio |
# | IN_TREINEIRO | Indica se o inscrito fez a prova com intuito de apenas treinar seus conhecimentos3 |
# | CO_MUNICIPIO_ESC | Código do município da escola |
# | NO_MUNICIPIO_ESC | Nome do município da escola |
# | CO_UF_ESC | Código da Unidade da Federação da escola |
# | SG_UF_ESC | Sigla da Unidade da Federação da escola |
# | TP_DEPENDENCIA_ADM_ESC | Dependência administrativa (Escola) |
# | TP_LOCALIZACAO_ESC | Localização (Escola) |
# | TP_SIT_FUNC_ESC | Situação de funcionamento (Escola) |
# | CO_MUNICIPIO_PROVA | Código do município da aplicação da prova |
# | NO_MUNICIPIO_PROVA | Nome do município da aplicação da prova |
# | CO_UF_PROVA | Código da Unidade da Federação da aplicação da prova |
# | SG_UF_PROVA | Sigla da Unidade da Federação da aplicação da prova |
# | TP_PRESENCA_CN | Presença na prova objetiva de Ciências da Natureza |
# | TP_PRESENCA_CH | Presença na prova objetiva de Ciências Humanas |
# | TP_PRESENCA_LC | Presença na prova objetiva de Linguagens e Códigos |
# | TP_PRESENCA_MT | Presença na prova objetiva de Matemática |
# | CO_PROVA_CN | Código do tipo de prova de Ciências da Natureza |
# | CO_PROVA_CH | Código do tipo de prova de Ciências Humanas |
# | CO_PROVA_LC | Código do tipo de prova |
# |NU_NOTA_CN |	Nota da prova de Ciências da Natureza  |
# |NU_NOTA_CH |	Nota da prova de Cieências Humanas |
# |NU_NOTA_LC |	Nota da prova de Linguagens e Códigos  |
# |NU_NOTA_MT |	Nota da prova de Matemática  |
# | TX_RESPOSTAS_CN |	Vetor com as respostas da parte objetiva da prova de Ciências da Natureza |
# | TX_RESPOSTAS_CH	 | Vetor com as respostas da parte objetiva da prova de Ciências Humanas |
# | TX_RESPOSTAS_LC |	Vetor com as respostas da parte objetiva da prova de Linguagens e Códigos |
# | TX_RESPOSTAS_MT | 	Vetor com as respostas da parte objetiva da prova de Matemática |
# | TP_LINGUA |	Língua Estrangeira |
# | TX_GABARITO_CN |	Vetor com o gabarito da parte objetiva da prova de Ciências da Natureza |
# |TX_GABARITO_CH |	Vetor com o gabarito da parte objetiva da prova de Ciências Humanas |
# | TX_GABARITO_LC | Vetor com o gabarito da parte objetiva da prova de Linguagens e Códigos |
# | TX_GABARITO_MT |	Vetor com o gabarito da parte objetiva da prova de Matemática |
# | TP_STATUS_REDACAO |	Situação da redação do participante |
# | NU_NOTA_COMP1	| Nota da competência 1 - Demonstrar domínio da modalidade escrita formal da Língua Portuguesa. |
# | NU_NOTA_COMP2	| Nota da competência 2 - Compreender a proposta de redação e aplicar conceitos das várias áreas de conhecimento para desenvolver o tema, dentro dos limites estruturais do texto dissertativo-argumentativo em prosa. |
# | NU_NOTA_COMP3	| Nota da competência 3 - Selecionar, relacionar, organizar e interpretar informações, fatos, opiniões e argumentos em defesa de um ponto de vista. |
# | NU_NOTA_COMP4	| Nota da competência 4 - Demonstrar conhecimento dos mecanismos linguísticos necessários para a construção da argumentação. |
# | NU_NOTA_COMP5	| Nota da competência 5 - Elaborar proposta de intervenção para o problema abordado, respeitando os direitos humanos.  |
# | NU_NOTA_REDACAO | Nota da prova de redação |
# | Q001	| Até que série seu pai, ou o homem responsável por você, estudou?   |
# | Q002	| Até que série sua mãe, ou a mulher responsável por você, estudou?  |
# | Q003	| A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação do seu pai ou do homem responsável por você. (Se ele não estiver trabalhando, escolha uma ocupação pensando no último trabalho dele). |
# | Q004	| A partir da apresentação de algumas ocupações divididas em grupos ordenados, indique o grupo que contempla a ocupação mais próxima da ocupação da sua mãe ou da mulher responsável por você. (Se ela não estiver trabalhando, escolha uma ocupação pensando no último trabalho dela).	|
# | Q005	| Incluindo você, quantas pessoas moram atualmente em sua residência? |
# | Q006	| Qual é a renda mensal de sua família? (Some a sua renda com a dos seus familiares.) |
# | Q007	| Em sua residência trabalha empregado(a) doméstico(a)?	|
# | Q008	| Na sua residência tem banheiro?  |
# | Q009	| Na sua residência tem quartos para dormir?  |
# | Q010	| Na sua residência tem carro?	|
# | Q011	| Na sua residência tem motocicleta? |
# | Q012	| Na sua residência tem geladeira?   |
# | Q013	| Na sua residência tem freezer (independente ou segunda porta da geladeira)?  |
# | Q014	| Na sua residência tem máquina de lavar roupa? (o tanquinho NÃO deve ser considerado) |
# | Q015	| Na sua residência tem máquina de secar roupa (independente ou em conjunto com a máquina de lavar roupa)? |
# | Q016	| Na sua residência tem forno micro-ondas? |
# | Q017	| Na sua residência tem máquina de lavar louça? |
# | Q018	| Na sua residência tem aspirador de pó?  |
# | Q019	| Na sua residência tem televisão em cores? |
# | Q020	| Na sua residência tem aparelho de DVD?    |
# | Q021	| Na sua residência tem TV por assinatura?  |
# | Q022	| Na sua residência tem telefone celular?   |
# | Q023	| Na sua residência tem telefone fixo?	    |
# | Q024	| Na sua residência tem computador?	    |
# | Q025	| Na sua residência tem acesso à Internet?  |

# %%
# Importação das bibliotecas utilizadas
import pandas as pd
from google.colab import drive
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import missingno as ms # para tratamento de missings
from matplotlib import cm
from pandas import set_option
from pandas.plotting import scatter_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
# configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 2. Carga de Dados

# %% [markdown]
# Usaremos o pacote Pandas para carregar o Arquivo .csv com cabeçalho. Foi necessário a utilização dos parâmetros delimiter e econding para a vizualização do dataset.
#
# Com o dataset carregado, iremos explorá-lo um pouco.

# %%
# url a importar
url_dados = 'https://liessin.com.br/mvp/enem_2021.csv'

# labels dos atributos do dataset
enem_br = pd.read_csv(url_dados,delimiter=';',encoding='ISO-8859-1')

# %% [markdown]
# COmo vou trabalhar com o campo de notas, vou renomear as colunas referentes pelo nome que esta no dicionario de dados do enem

# %%
# Dicionário com as descrições das áreas de conhecimento
areas_conhecimento = {
    'NU_NOTA_CN': 'Ciências da Natureza',
    'NU_NOTA_CH': 'Ciências Humanas',
    'NU_NOTA_LC': 'Linguagens e Códigos',
    'NU_NOTA_MT': 'Matemática',
    'NU_NOTA_REDACAO': 'Redação'
}
# Renomeando as colunas com as descrições das áreas de conhecimento
enem_br = enem_br.rename(columns=areas_conhecimento)

#Criando uma variavél notas_cols com as colunas de notas do dataset
notas_cols = ['Ciências da Natureza', 'Ciências Humanas', 'Linguagens e Códigos', 'Matemática', 'Redação']

# %%
#mostrar todas as colunas do dataset
pd.set_option('display.max_columns', None)
# exibe as 5 primeiras tuplas e as 5 últimas
display(enem_br)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# ## 3. Análise de Dados

# %% [markdown]
# ### 3.1. Estatísticas Descritivas
#
# Vamos iniciar examinando as dimensões do dataset, suas informações e alguns exemplos de linhas.

# %%
#Verificando o tamanho do dataset
enem_br.shape
# Out:
# (3389832, 76)

# %% [markdown]
# O Dataset contém 3.389.832 tuplas com 76 colunas. Abaixo veirificaremos as informações das colunas e o tipo de dado de cada um.

# %%
# Mostra as informações do dataset
print(enem_br.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3389832 entries, 0 to 3389831
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_INSCRICAO            int64
#  1   NU_ANO                  int64
#  2   TP_FAIXA_ETARIA         int64
#  3   TP_SEXO                 object
#  4   TP_ESTADO_CIVIL         int64
#  5   TP_COR_RACA             int64
#  6   TP_NACIONALIDADE        int64
#  7   TP_ST_CONCLUSAO         int64
#  8   TP_ANO_CONCLUIU         int64
#  9   TP_ESCOLA               int64
#  10  TP_ENSINO               float64
#  11  IN_TREINEIRO            int64
#  12  CO_MUNICIPIO_ESC        float64
#  13  NO_MUNICIPIO_ESC        object
#  14  CO_UF_ESC               float64
#  15  SG_UF_ESC               object
#  16  TP_DEPENDENCIA_ADM_ESC  float64
#  17  TP_LOCALIZACAO_ESC      float64
#  18  TP_SIT_FUNC_ESC         float64
#  19  CO_MUNICIPIO_PROVA      int64
#  20  NO_MUNICIPIO_PROVA      object
# ...

# %% [markdown]
#  Analisando as colunas e tipos de dados, comparando com o dicionário de dados do dataset vai ser necessária a escolha de algumas colunas que não são o objeto de pesquisa do dataset.
#
# Abaixo iremos verificar as primeiras e ultimas linhas do dataset, para ter algum insight inicial.

# %%
# Mostra as 10 primeiras linhas do dataset
enem_br.head(10)
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
# 5  210052391248    2021               10       F                1
# 6  210052615524    2021                9       F                0
# 7  210054368957    2021                4       F                1
# 8  210053417016    2021                8       F                1
# 9  210051128744    2021                4       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# ...

# %%
# Mostra as 10 últimas linhas do dataset
enem_br.tail(10)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 3389822  210054424628    2021               10       F                1
# 3389823  210051676080    2021                8       M                1
# 3389824  210052788373    2021               13       F                3
# 3389825  210053818244    2021                5       F                1
# 3389826  210052408816    2021                9       F                1
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# 3389822            3                 1                1                7
# ...

# %% [markdown]
# Observando essas linhas pecebemos que temos muitos campos referentes a notas nulos de candidatos que provavelmente faltaram a prova ou foram eliminados, sendo necessário na fase pré-processamento eliminá-las ou preenche-las conforme a necessidade. Não notado nenhum campo discrepante.
#
# Nesta seção farei um resumo estatistico somente com as colunas que contem as notas das áreas de conhecimento que o
# candidato foi avaliado, inicalmente meu objeto de analise.

# %%
# Faz um resumo estatístico do dataset (média, desvio padrão, mínimo, máximo e os quartis)
enem_br[notas_cols].describe().round(2)
# Out:
#        Ciências da Natureza  Ciências Humanas  Linguagens e Códigos  \
# count            2245844.00        2378379.00            2378379.00
# mean                 491.79            519.94                502.56
# std                   80.57             95.79                 79.16
# min                    0.00              0.00                  0.00
# 25%                  431.00            445.40                447.60
# 50%                  482.00            521.90                505.90
# 75%                  545.80            589.30                558.80
# max                  867.10            846.90                826.10
#
#        Matemática     Redação
# count  2245844.00  2378379.00
# mean       535.08      613.50
# std        110.63      190.71
# min          0.00        0.00
# 25%        444.70      520.00
# 50%        515.40      600.00
# 75%        613.90      740.00
# max        953.10     1000.00

# %% [markdown]
# Avalio que temos notas mínimas 0 em todas as areas de avaliação, tambem que o contador de linhas foi para 2.245.844, insinuando um numero muito alto de notas nulas. Pode ser que existam um numero consideravel de candidatos que faltaram a prova, isso se dat pelo ano de pandemia que viviámos na época. vou criar um atributo no dataset faltou, para trabalhar no futuro.

# %%
# Cria uma nova coluna que indica se o aluno faltou em alguma das provas
enem_br['faltou'] = (enem_br['TP_PRESENCA_CN'] == 0) | (enem_br['TP_PRESENCA_CH'] == 0) | (enem_br['TP_PRESENCA_MT'] == 0)
display(enem_br)
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %% [markdown]
# Vamos calcular a moda das avaliações.

# %%
#Calculando a Moda
moda = enem_br[notas_cols].mode()
print("Moda:\n",moda)
# Out:
# Moda:
#     Ciências da Natureza  Ciências Humanas  Linguagens e Códigos  Matemática  \
# 0                 428.6               0.0                   0.0       427.8
#
#    Redação
# 0    560.0

# %% [markdown]
# Constato que existem moda 0 na notas de Ciências Humanas (NU_NOTA_CH) e Linguagens e Códigos(NU_NOTA_LC). Vou listar a quantidade de notas 0 de todas as avaliações.

# %%
num_rows_cn = enem_br.loc[enem_br['Ciências da Natureza'] == 0].shape[0]
print("Número de linhas com notas de Ciências da Natureza igual a zero: ", num_rows_cn)
num_rows_ch = enem_br.loc[enem_br['Ciências Humanas'] == 0].shape[0]
print("Número de linhas com notas de Ciências Humanas igual a zero: ", num_rows_ch)
num_rows_lc = enem_br.loc[enem_br['Linguagens e Códigos'] == 0].shape[0]
print("Número de linhas com notas de Linguagens e Códigos igual a zero: ", num_rows_lc)
num_rows_mt = enem_br.loc[enem_br['Matemática'] == 0].shape[0]
print("Número de linhas com notas de Matemática igual a zero: ", num_rows_mt)
num_rows_redacao = enem_br.loc[enem_br['Redação'] == 0].shape[0]
print("Número de linhas com notas de Redação igual a zero: ", num_rows_redacao)
# Out:
# Número de linhas com notas de Ciências da Natureza igual a zero:  393
# Número de linhas com notas de Ciências Humanas igual a zero:  4632
# Número de linhas com notas de Linguagens e Códigos igual a zero:  2248
# Número de linhas com notas de Matemática igual a zero:  453
# Número de linhas com notas de Redação igual a zero:  84582

# %% [markdown]
# Vou agrupar para enternder melhor esse numero elevado de zeros nessas duas áreas.

# %%
# Agrupando as notas de Ciências Humanas  e  Linguagens e Codigos por nota.

counts_ch = enem_br['Ciências da Natureza'].value_counts()
print(counts_ch)

counts_lc = enem_br['Linguagens e Códigos'].value_counts()
print(counts_ch)
# Out:
# 428.6    1218
# 450.7    1214
# 446.5    1206
# 460.8    1197
# 445.6    1195
#          ...
# 819.4       1
# 799.2       1
# 823.2       1
# 825.7       1
# 323.1       1
# Name: Ciências da Natureza, Length: 5030, dtype: int64
# 428.6    1218
# 450.7    1214
# 446.5    1206
# 460.8    1197
# 445.6    1195
#          ...
# 819.4       1
# 799.2       1
# 823.2       1
# 825.7       1
# 323.1       1
# Name: Ciências da Natureza, Length: 5030, dtype: int64

# %% [markdown]
# Quando executamos o comando acima explica a mediana zero para essas duas avaliações ja que contando os valores de notas tiradas, o zero é maior que todas as outras.

# %% [markdown]
# ### 3.2. Visualizações Unimodais
#
# Vamos criar agora um histograma para cada atributo de notas  do dataset.

# %%
# Cria os histogramas
enem_br[notas_cols].hist(bins=30, figsize=(12,8), alpha=0.5, grid=True, color='green', edgecolor='black')

# Define os títulos dos histogramas
plt.suptitle('Distribuição das Notas do ENEM 2021 por Área de Conhecimento', fontsize=20)

# Define o título do eixo x
plt.xlabel('Notas', fontsize=15)

# Define o título do eixo y
plt.ylabel('Frequência', fontsize=15)

# Mostra o gráfico
plt.show()

# %% [markdown]
# Algumas analises de cada atributo podemos fazer com esse historgrama:
#
# **NU_NOTA_CN** - Ciências da Natureza - a nota máxima 1000 não foi atingida, a nota modal foi entorno de 430, a nota máxima ficou em 860, a maoir concentração ficou entre as notas 450 e 560. Podemos dizer que a maior parte das notas estão entorno da medida central, ou média.
#
# **NU_NOTA_CH** - Ciências Humanas - a nota máxima 1000 não foi atingida, a nota modal foi entorno de 450, a nota máxima ficou em 846, a maoir concentração ficou entre as notas 410 e 600. Mostra uma conformidade das notas, sendo quase um platô na média das notas.
#
# **NU_NOTA_LC** - Linguagens e Códigos - a nota máxima 1000 não foi atingida e foi a menor nota máxima entre as áreas avalianas, a nota modal foi entorno de 550, a nota máxima ficou em 826, a maoir concentração ficou entre as notas 500 e 600. Podemos dizer que a maior parte das notas estão entorno da medida central, ou média.
#
# **NU_NOTA_MT** - Matemática - Teve a segunda maior nota maxima com pontuação acima dos 900, a nota modal foi entorno de 410, a maior concentração de notas foi entre 400 e 600. Indica que a baixa frequencia das maiores notas demonstrando um histograma tipo cauda a direita".
#
#
# **NU_NOTA_REDACAO** - Redação - Foi a unica avaliação com nota maxima, porem com uma distribuição maior dentro do grafico, tendo alguns picos, sendo um histograma multimodal, tendo tembém o maoir numero de candidatos que zeraram a prova.

# %% [markdown]
# No caso do Enem, é esperado que a maioria dos alunos tenha notas na faixa intermediária, enquanto um número menor de alunos obtém notas muito baixas ou muito altas, por isso no **boxplot** abaixo parece que nas avaliações analisadas existem outliers, porem não são. Existe um percentual dos alunos que tiram notas muito altas ou muito baixas. Essas notas compões um calculo para chegar a pontuação geral do aluno. Esse cálculo varia de universidade para universidade.

# %%
# Selecionar as colunas com as notas de cada área de conhecimento
notas = enem_br[notas_cols]

# Criar um gráfico boxplot para cada nota
for i, coluna in enumerate(notas):
    plt.figure(i)
    plt.boxplot(notas[coluna].dropna())
    plt.xlabel('Notas')
    plt.ylabel('Frequência')
    plt.title('Distribuição das notas em %s' % coluna)

plt.show()

# %% [markdown]
# Abaixo verificaremos a analise das inscrições em areas urbanas e rurais

# %%
# Conta a quantidade de alunos por localização
localizacao_counts = enem_br['TP_LOCALIZACAO_ESC'].value_counts()

# Cria um gráfico de pizza com a distribuição por localização
localizacao_counts.plot(kind='pie', figsize=(4,4), autopct='%1.1f%%', startangle=90, 
                        colors=['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'orange', 'purple'])

# Define os rótulos para cada tipo de localização
tipos_localizacao = ["Urbana", "Rural", "Não informado"]
plt.legend(labels=tipos_localizacao, loc="best")

# Define o título do gráfico
plt.title('Distribuição dos alunos do ENEM 2021 por localização de escola', fontsize=10)

# Mostra o gráfico
plt.show()

# %% [markdown]
# Vemos que seomente 3,5% da população que se inscreveu no ENEM 2021 é de área Rural.

# %% [markdown]
# ### 3.3. Visualizações Multimodais
# Vou exibir abaixo a matriz de correlação entre os atibutos de notas do dataset, para entender se existe uma correlação positiva ou negativa entre as notas em suas áreas de conhecimento.

# %%
# Matriz de Correlação com Matplotlib Seaborn
sns.heatmap(enem_br[notas_cols].corr(), annot=True, cmap='RdBu');

# %% [markdown]
# Após a geração da matriz de correlação, notamos entre toda as notas positiva, chama atenção que a correlação entre as notas de Liguagens e Codigos com a de Ciencias Humanas quem fez uma boa pontuação em uma área também fez na outra. t

# %% [markdown]
# Por sua vez, o gráfico de dispersão (**scatter plot**) mostra o relacionamento entre duas variáveis. Vamos exibir um para cada par de atributos dos dataset, usando o Seaborn.

# %%
# Scatter Plot com Seaborn - Variação 1
# selecione uma amostra aleatória dos dados
sample_size = 10000  # ajuste esse valor para alterar o tamanho da amostra
df_sample = enem_br[notas_cols].sample(n=sample_size, random_state=42)

# crie a matriz de gráficos de dispersão
sns.pairplot(data=df_sample, diag_kind='hist', height=2.5)

# exiba a plotagem
plt.show()

# %%
# Scatter Plot com Seaborn - Variação 2
sample_size = 10000  # ajuste esse valor para alterar o tamanho da amostra
df_sample = enem_br[notas_cols].sample(n=sample_size, random_state=42)
sns.pairplot(data=df_sample, hue = "Redação", height = 2.5, palette="coolwarm");

# %% [markdown]
# A plotagem do grafico acima confirma as correlações positivas entra as notas, notamos uma certa linearidade entre as notas em todos os graficos. Na segunda variação fizemos as notas comparadas com a nota de redação, assim sendo, podemos notar que as notas mais altas de redação são tambem correlacionadas as notas mais altas das demais avaliações.

# %% [markdown]
# Usando um outro angulo de analise vou verificar a distribuição de inscrição por estado.

# %%
# Conta a quantidade de alunos por estado
estado_counts = enem_br['SG_UF_ESC'].value_counts()

# Divide a contagem por 1000 e formata em milhares
estado_counts_formatado = estado_counts.apply(lambda x: '{:.1f}k'.format(x/1e3))

# Cria um gráfico de barras com a distribuição por estado
estado_counts.plot(kind='bar', figsize=(15,8), color='green', edgecolor='black')

# Adiciona as etiquetas com a quantidade formatada de alunos nas barras
for i, v in enumerate(estado_counts):
    plt.text(i - 0.1, v + 500, estado_counts_formatado[i], fontsize=12)

# Define o título do gráfico
plt.title('Distribuição dos alunos do ENEM 2021 por estado', fontsize=20)

# Define o título do eixo x
plt.xlabel('Estados', fontsize=15)

# Define o título do eixo y
plt.ylabel('Quantidade de alunos', fontsize=15)

# Mostra o gráfico
plt.show()

# %% [markdown]
# No grafico acima notamos que o Estado de São Paulo tem um numero de inscrições extremamente maior que os outros estados, isso se dá pelo maior numero de habitantes no estado que é de dobro, 41 milhoes  em relação ao segundo que é Minas gerais com 19milhoes segundo dados do IBGE de 2010. O interessante que o Ceará o segundo lugar em inscrições é somente o 8º lugar em numero de população.
#
# Fonte : [https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3ok](https://)
# ```

# %% [markdown]
# O Grafico de linha abaixo demonstra a media das notas tiradas pelos candidatos em relação a que série do pai, ou o homem responsável pelo candidato estudou. Reparamos que quanto mais estudo esse responsável teve a media do candidato é maior.

# %%
# Selecionando as colunas relevantes
notas_df = enem_br[['Q001', 'Ciências da Natureza', 'Ciências Humanas', 'Linguagens e Códigos', 'Matemática', 'Redação']]

# Substituindo os códigos pelos textos correspondentes
notas_df['Q001'] = notas_df['Q001'].replace({
    'A': '00 - Nunca estudou', 
    'B': '01 - Não completou a 4ª série/5º ano', 
    'C': '02 - Completou até a 8ª série/9º ano', 
    'D': '03 - Completou o Ensino Fundamental', 
    'E': '04 - Completou o Ensino Médio', 
    'F': '05 - Completou a Faculdade', 
    'G': '06 - Completou a Pós-graduação', 
    'H': '07 - Não sei'
})

# Agrupando os dados por grau de instrução do homem da casa e calculando a mediana das notas
notas_grouped = notas_df.groupby('Q001').mean()

# Plotando um gráfico de linhas para comparar as medianas das notas do Enem para cada nível de instrução
notas_grouped.T.plot(kind='line', figsize=(10, 6), grid=True)

# Configurando as legendas
plt.title('Medias das notas do Enem por grau de instrução do homem da casa')
plt.xlabel('Áreas de conhecimento')
plt.ylabel('Nota mediana do Enem')
plt.legend(title='Grau de instrução do homem da casa', loc='upper left', bbox_to_anchor=(1.05, 1))

# Mostrando o gráfico
plt.show()

# %% [markdown]
# O próximo grafico é somente de medianas das notas avaliadas em cada área de conhecimento.

# %%
# Selecionando as colunas relevantes
enem_df = enem_br[['Ciências da Natureza', 'Ciências Humanas', 'Linguagens e Códigos', 'Matemática', 'Redação']]

# Calculando as medianas das notas para cada área de conhecimento
enem_medians = enem_df.median()

# Plotando um gráfico de linhas para comparar as medianas de notas do Enem para cada área de conhecimento
enem_medians.plot(kind='line', figsize=(10, 6), marker='o')

# Definindo o título e os rótulos dos eixos
plt.title('Medianas de notas do Enem por área de conhecimento')
plt.xlabel('Área de conhecimento')
plt.ylabel('Mediana da nota do Enem')

# Adicionando os valores das medianas nas barras
for i, value in enumerate(enem_medians):
    plt.text(i, value, f'{value:.1f}', ha='center')

# Mostrando o gráfico
plt.show()

# %% [markdown]
# ## 4. Pré-Processamento de dados

# %% [markdown]
# ### 4.1. Tratamento de Missings e Limpeza

# %% [markdown]
# O datset do microdados do enem existem muitos dados nulos de candidatos que faltaram as provas ou foram eliminados.

# %%
# verificando nulls no dataset
enem_br[notas_cols].isnull().sum()
# Out:
# Ciências da Natureza    1143988
# Ciências Humanas        1011453
# Linguagens e Códigos    1011453
# Matemática              1143988
# Redação                 1011453
# dtype: int64

# %% [markdown]
# Existem quase 1/3 das notas nulas. Vamos criar um novo dataset  com quem estava não faltou a prova e tem nota valida.

# %%
# Selecione as linhas que não possuem notas nulas e que não têm faltas registradas
enem_br_sem_nulos = enem_br.loc[(enem_br['Ciências da Natureza'].notnull()) & 
                                (enem_br['Ciências Humanas'].notnull()) & 
                                (enem_br['Linguagens e Códigos'].notnull()) & 
                                (enem_br['Matemática'].notnull()) &
                                (enem_br['TP_PRESENCA_CN'] == 1) & 
                                (enem_br['TP_PRESENCA_CH'] == 1) & 
                                (enem_br['TP_PRESENCA_LC'] == 1) &
                                (enem_br['TP_PRESENCA_MT'] == 1) &
                                (enem_br['faltou'] == False)]

# verificando nulls no dataset
enem_br_sem_nulos[notas_cols].isnull().sum()
# Out:
# Ciências da Natureza    0
# Ciências Humanas        0
# Linguagens e Códigos    0
# Matemática              0
# Redação                 0
# dtype: int64

# %% [markdown]
# Verificando o tamanho do novo dataset

# %%
enem_br_sem_nulos.shape
# Out:
# (2238107, 77)

# %% [markdown]
# Vamos mostrar o dataset original em uma visualização matricial.

# %%
# salvando um NOVO dataset para tratamento de missings (cuidado para não sobrescrever o dataset original!)

# recuperando os nomes das colunas
#col = list(enem_br[notas_cols])

# o novo dataset irá conter todas as colunas referente a notas
atributos = enem_br[notas_cols]

# exibindo visualização matricial da nulidade do dataset
ms.matrix(atributos)
# Out:
# <Axes: >

# %% [markdown]
# A matriz de visualização informa um grande numero de missings, vamos verificar a mesma matriz de visualização no dataset sem missings das notas criado em um passo anterior.

# %%
# salvando um NOVO dataset para tratamento de missings (cuidado para não sobrescrever o dataset original!)

# recuperando os nomes das colunas
col = list(enem_br_sem_nulos[notas_cols])

# o novo dataset irá conter todas as colunas com exceção da última (faltou)
atributos = enem_br_sem_nulos[notas_cols]

# exibindo visualização matricial da nulidade do dataset
ms.matrix(atributos)
# Out:
# <Axes: >

# %% [markdown]
# Vamos notar que não retiramos as notas zero de quem participou efetivamente da prova, pois é um dado valido, para o calculo da pontuação do candidato. Verificaremos isso nos comando abaixo.

# %%
num_rows_cn = enem_br_sem_nulos.loc[enem_br_sem_nulos['Ciências da Natureza'] == 0].shape[0]
print("Número de linhas com notas de Ciências da Natureza igual a zero: ", num_rows_cn)
num_rows_ch = enem_br_sem_nulos.loc[enem_br_sem_nulos['Ciências Humanas'] == 0].shape[0]
print("Número de linhas com notas de Ciências Humanas igual a zero: ", num_rows_ch)
num_rows_lc = enem_br_sem_nulos.loc[enem_br_sem_nulos['Linguagens e Códigos'] == 0].shape[0]
print("Número de linhas com notas de Linguagens e Códigos igual a zero: ", num_rows_lc)
num_rows_mt = enem_br_sem_nulos.loc[enem_br_sem_nulos['Matemática'] == 0].shape[0]
print("Número de linhas com notas de Matemática igual a zero: ", num_rows_mt)
num_rows_redacao = enem_br_sem_nulos.loc[enem_br_sem_nulos['Redação'] == 0].shape[0]
print("Número de linhas com notas de Redação igual a zero: ", num_rows_redacao)
# Out:
# Número de linhas com notas de Ciências da Natureza igual a zero:  275
# Número de linhas com notas de Ciências Humanas igual a zero:  2230
# Número de linhas com notas de Linguagens e Códigos igual a zero:  801
# Número de linhas com notas de Matemática igual a zero:  364
# Número de linhas com notas de Redação igual a zero:  62663

# %% [markdown]
# ### 4.2. Separação em conjunto de treino e conjunto de teste
#
# Neste passo irei criar um novo dataset com os dados originais, excluirei a coluna da avaliação de Redação. Dessa forma, estou separando os atributos de entrada (as colunas de notas, armazenadas em X) do atributo de saída (a coluna NU_NOTA_REDACAO, armazenada em y). Isso é importante para treinar um modelo de aprendizado de máquina, pois o modelo usará as notas de Ciências da Natureza, Ciências Humanas, Linguagens e Códigos e Matemática como entradas para prever a nota de Redação.
# Inicialmente farei essa separação com o dataset original

# %%
#criando o novo dataset enem_notas
enem_notas = enem_br[notas_cols]

# Verificando e removendo os valores ausentes, se houver
enem_notas.isna().sum()
enem_notas = enem_notas.dropna()

# Definindo o tamanho do conjunto de teste e a semente do gerador de números aleatórios
test_size = 0.3 # tamanho do conjunto de teste
seed = 42 # semente do gerador de números aleatórios

# Separando o conjunto de dados em conjuntos de treino e teste
X = enem_notas.drop('Redação', axis=1) # atributos de entrada
y = enem_notas['Redação'] # atributo de saída (target)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)

# %% [markdown]
# #### 4.2.1 Normatização e Padronização
#
# Vamos aplicar a tecnica de Normatização para o conjunto de dados modificado e depois separa-los novamente para treino e teste.

# %%
# cria uma instância do MinMaxScaler
scaler = MinMaxScaler()

# separa as notas em uma matriz
notas = enem_br_sem_nulos[notas_cols]

# aplica o MinMaxScaler às notas
notas_norm = scaler.fit_transform(notas)
print("Dados Originais: \n\n",notas)
print("Dados Normatizados: \n\n",notas_norm)

print("Separando o conjunto de dados em conjuntos de treino e teste....")
# Verificando e removendo os valores ausentes, se houver
notas.isna().sum()
notas = notas.dropna()

# Definindo o tamanho do conjunto de teste e a semente do gerador de números aleatórios
test_size = 0.3 # tamanho do conjunto de teste
seed = 42 # semente do gerador de números aleatórios

# Separando o conjunto de dados em conjuntos de treino e teste
X = notas.drop('Redação', axis=1) # atributos de entrada
y = notas['Redação'] # atributo de saída (target)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
# Out:
# Dados Originais:
#
#           Ciências da Natureza  Ciências Humanas  Linguagens e Códigos  \
# 1                       505.9             551.8                 498.3
# 3                       580.7             678.9                 638.9
# 4                       497.7             532.4                 457.6
# 8                       487.4             476.5                 450.7
# 9                       507.6             539.2                 494.6
# ...                       ...               ...                   ...
# 3389793                 506.0             405.2                 416.3
# 3389807                 435.6             531.2                 534.7
# 3389814                 576.9             605.6                 631.0
# 3389815                 449.9             368.2                 466.3
# 3389830                 563.7             646.0                 550.7
#
#          Matemática  Redação
# 1             461.5    560.0
# 3             659.5    780.0
# ...
