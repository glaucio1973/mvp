# %% [markdown]
# <a href="https://colab.research.google.com/github/glaucio1973/mvp/blob/master/manipulando_cats_versus_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Manuipilando dados
# ## Gatos

# %%
# carregabdo o Os e o Drive
import os

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#carregando o diretorio e dando novo nome ao aqruivo
diretorio = '/content/drive/MyDrive/Colab Notebooks/Imagens/Cat'
novo_formato = 'cat.{0}.jpg'

# %%
# Obtém a lista de arquivos no diretório
arquivos = os.listdir(diretorio)
print(f"Temos um total de {len(os.listdir(diretorio))} imagens para o treinamento e avaliação do modelo de deep learning")
print(f"Primeiras 20 imagens: \n {os.listdir(diretorio)[:20]}")
# Out:
# Temos um total de 1051 imagens para o treinamento e avaliação do modelo de deep learning
# Primeiras 20 imagens:
#  ['470.jpg', '468.jpg', '474.jpg', '471.jpg', '473.jpg', '469.jpg', '47.jpg', '472.jpg', '455.jpg', '460.jpg', '458.jpg', '456.jpg', '459.jpg', '46.jpg', '457.jpg', '454.jpg', '453.jpg', '452.jpg', '451.jpg', '450.jpg']

# %%
# Percorre a lista de arquivos e renomeando os arquivos
for i, arquivo in enumerate(arquivos):
    # Verifica se é um arquivo de imagem
    if arquivo.endswith(('.jpg', '.png', '.jpeg')):
        # Mostra o nome original do arquivo
        print("Nome original:", arquivo)

        # Gera o novo nome no formato desejado
        novo_nome = novo_formato.format(i + 1)

        # Caminho completo do arquivo original
        caminho_original = os.path.join(diretorio, arquivo)

        # Caminho completo do arquivo renomeado
        caminho_novo = os.path.join(diretorio, novo_nome)

        # Renomeia o arquivo
        os.rename(caminho_original, caminho_novo)

        # Mostra o novo nome do arquivo
        print("Novo nome:", novo_nome)
        print()

# %%
print(f"Temos um total de {len(os.listdir(diretorio))} imagens para o treinamento e avaliação do modelo de deep learning")
print(f"Primeiras 20 imagens: \n {os.listdir(diretorio)[:20]}")
# Out:
# Temos um total de 1052 imagens para o treinamento e avaliação do modelo de deep learning
# Primeiras 20 imagens:
#  ['cat.1.jpg', 'cat.2.jpg', 'cat.3.jpg', 'cat.4.jpg', 'cat.5.jpg', 'cat.6.jpg', 'cat.7.jpg', 'cat.8.jpg', 'cat.9.jpg', 'cat.10.jpg', 'cat.11.jpg', 'cat.12.jpg', 'cat.13.jpg', 'cat.14.jpg', 'cat.15.jpg', 'cat.16.jpg', 'cat.17.jpg', 'cat.18.jpg', 'cat.19.jpg', 'cat.20.jpg']

# %%
import os
import shutil

diretorio_atual = C
pasta_imagens = '/content/drive/MyDrive/Colab Notebooks/Imagens'  # Caminho relativo para a pasta de imagens
caminho_completo = os.path.join(diretorio_atual, pasta_imagens)
caminho_destino = os.path.join(diretorio_atual, 'train')


# Criar o diretório 'train' se ele não existir
if not os.path.exists(caminho_destino):
    os.makedirs(caminho_destino)
print(caminho_destino)
print(f"Temos um total de {len(os.listdir(caminho_destino))} imagens para o treinamento e avaliação do modelo de deep learning")
print(f"Primeiras 20 imagens: \n {os.listdir(caminho_destino)[:20]}")
# Out:
# /content/drive/MyDrive/Colab Notebooks/Imagens/train
# Temos um total de 0 imagens para o treinamento e avaliação do modelo de deep learning
# Primeiras 20 imagens:
#  []

# %%
import os
import shutil

diretorio_origem = '/content/drive/MyDrive/Colab Notebooks/Imagens/Cat'
diretorio_destino = '/content/drive/MyDrive/Colab Notebooks/Imagens/train'

# Criar o diretório de destino se ele não existir
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Obtém a lista de arquivos no diretório de origem
arquivos = os.listdir(diretorio_origem)

# Percorre a lista de arquivos
for arquivo in arquivos:
    # Verifica se o nome do arquivo contém a palavra "cat"
    if 'cat' in arquivo.lower():
        # Caminho completo do arquivo de origem
        caminho_origem = os.path.join(diretorio_origem, arquivo)

        # Caminho completo do arquivo de destino
        caminho_destino = os.path.join(diretorio_destino, arquivo)

        # Copia o arquivo para o diretório de destino
        shutil.copy(caminho_origem, caminho_destino)

print("Os arquivos contendo 'cat' no nome foram copiados para o diretório 'train'.")
# Out:
# Os arquivos contendo 'cat' no nome foram copiados para o diretório 'train'.

# %% [markdown]
# ## Cães

# %%
#carregando o diretorio e dando novo nome ao aqruivo
diretorio = '/content/drive/MyDrive/Colab Notebooks/Imagens/Dog'
novo_formato = 'dog.{0}.jpg'

# %%
# Obtém a lista de arquivos no diretório
arquivos = os.listdir(diretorio)
print(f"Temos um total de {len(os.listdir(diretorio))} imagens para o treinamento e avaliação do modelo de deep learning")
print(f"Primeiras 20 imagens: \n {os.listdir(diretorio)[:20]}")
# Out:
# Temos um total de 1051 imagens para o treinamento e avaliação do modelo de deep learning
# Primeiras 20 imagens:
#  ['917.jpg', '733.jpg', '732.jpg', '739.jpg', '736.jpg', '738.jpg', '735.jpg', '734.jpg', '740.jpg', '737.jpg', '719.jpg', '718.jpg', '726.jpg', '727.jpg', '722.jpg', '724.jpg', '72.jpg', '720.jpg', '723.jpg', '725.jpg']

# %%
# Percorre a lista de arquivos e renomeando os arquivos
for i, arquivo in enumerate(arquivos):
    # Verifica se é um arquivo de imagem
    if arquivo.endswith(('.jpg', '.png', '.jpeg')):
        # Mostra o nome original do arquivo
        print("Nome original:", arquivo)

        # Gera o novo nome no formato desejado
        novo_nome = novo_formato.format(i + 1)

        # Caminho completo do arquivo original
        caminho_original = os.path.join(diretorio, arquivo)

        # Caminho completo do arquivo renomeado
        caminho_novo = os.path.join(diretorio, novo_nome)

        # Renomeia o arquivo
        os.rename(caminho_original, caminho_novo)

        # Mostra o novo nome do arquivo
        print("Novo nome:", novo_nome)
        print()
# Out:
# Nome original: 917.jpg
# Novo nome: dog.1.jpg
#
# Nome original: 733.jpg
# Novo nome: dog.2.jpg
#
# Nome original: 732.jpg
# Novo nome: dog.3.jpg
#
# Nome original: 739.jpg
# Novo nome: dog.4.jpg
#
# Nome original: 736.jpg
# Novo nome: dog.5.jpg
#
# Nome original: 738.jpg
# Novo nome: dog.6.jpg
#
# Nome original: 735.jpg
# Novo nome: dog.7.jpg
#
# Nome original: 734.jpg
# Novo nome: dog.8.jpg
#
# Nome original: 740.jpg
# Novo nome: dog.9.jpg
#
# Nome original: 737.jpg
# Novo nome: dog.10.jpg
#
# Nome original: 719.jpg
# Novo nome: dog.11.jpg
#
# Nome original: 718.jpg
# Novo nome: dog.12.jpg
#
# Nome original: 726.jpg
# Novo nome: dog.13.jpg
#
# Nome original: 727.jpg
# Novo nome: dog.14.jpg
#
# Nome original: 722.jpg
# Novo nome: dog.15.jpg
#
# Nome original: 724.jpg
# Novo nome: dog.16.jpg
#
# Nome original: 72.jpg
# Novo nome: dog.17.jpg
#
# Nome original: 720.jpg
# Novo nome: dog.18.jpg
#
# Nome original: 723.jpg
# Novo nome: dog.19.jpg
#
# Nome original: 725.jpg
# ...

# %%
import os
import shutil

diretorio_origem = '/content/drive/MyDrive/Colab Notebooks/Imagens/Dog'
diretorio_destino = '/content/drive/MyDrive/Colab Notebooks/Imagens/train'

# Criar o diretório de destino se ele não existir
if not os.path.exists(diretorio_destino):
    os.makedirs(diretorio_destino)

# Obtém a lista de arquivos no diretório de origem
arquivos = os.listdir(diretorio_origem)

# Percorre a lista de arquivos
for arquivo in arquivos:
    # Verifica se o nome do arquivo contém a palavra "dog"
    if 'dog' in arquivo.lower():
        # Caminho completo do arquivo de origem
        caminho_origem = os.path.join(diretorio_origem, arquivo)

        # Caminho completo do arquivo de destino
        caminho_destino = os.path.join(diretorio_destino, arquivo)

        # Copia o arquivo para o diretório de destino
        shutil.copy(caminho_origem, caminho_destino)

print("Os arquivos contendo 'cat' no nome foram copiados para o diretório 'train'.")
# Out:
# Os arquivos contendo 'cat' no nome foram copiados para o diretório 'train'.

# %%
import os

diretorio = '/content/drive/MyDrive/Colab Notebooks/Imagens/train'

# Obtém a lista de arquivos no diretório
arquivos = os.listdir(diretorio)

# Contadores
contador_cat = 0
contador_dog = 0

# Percorre a lista de arquivos
for arquivo in arquivos:
    if arquivo.lower().startswith('cat'):
        contador_cat += 1
    elif arquivo.lower().startswith('dog'):
        contador_dog += 1

# Exibe a quantidade de arquivos
print("Quantidade de arquivos iniciados com 'cat':", contador_cat)
print("Quantidade de arquivos iniciados com 'dog':", contador_dog)
# Out:
# Quantidade de arquivos iniciados com 'cat': 1051
# Quantidade de arquivos iniciados com 'dog': 1051
